# %%
print("ok")
# Out:
# ok

# %%
from dotenv import load_dotenv
import os

# Load environment variables from .env file
load_dotenv()

# Verify API key is loaded
api_key = os.getenv("GROQ_API_KEY")
if api_key:
    print("✅ GROQ_API_KEY loaded successfully")
else:
    print("❌ GROQ_API_KEY not found. Please set it in your .env file or environment.")
# Out:
# ✅ GROQ_API_KEY loaded successfully

# %%
from langchain_groq import ChatGroq

# %%
llm = ChatGroq(model="meta-llama/llama-4-scout-17b-16e-instruct")

# %%
llm.invoke("What is the capital of France?")
# Out:
# AIMessage(content='The capital of France is Paris.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 17, 'total_tokens': 25, 'completion_time': 0.018437341, 'completion_tokens_details': None, 'prompt_time': 0.000149217, 'prompt_tokens_details': None, 'queue_time': 0.020259371, 'total_time': 0.018586558}, 'model_name': 'meta-llama/llama-4-scout-17b-16e-instruct', 'system_fingerprint': 'fp_f08cd12a81', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019e1941-f7d3-7742-9a5e-2f9a71f6451f-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 17, 'output_tokens': 8, 'total_tokens': 25})
